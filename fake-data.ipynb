# %% [markdown]
# NOTEBOOK CRIADO PARA TESTAR A ROTINA LOCALMENTE

# %%
import mysql.connector
import pymysql
import datetime as dt
import pandas as pd
from sqlalchemy import create_engine
from faker import Faker

# %%
fake = Faker(locale='pt_BR')
volume = []

for _ in range(10):
    
      volume.append ({
          'prefix': fake.prefix_nonbinary(),
          'name': fake.name_nonbinary(),
          'suffix': fake.suffix_nonbinary(),
          'phone': fake.phone_number(),
          'email': fake.ascii_free_email(),
          'address': fake.address()
      })
    
df = pd.DataFrame(volume)

df
# Out:
#   prefix                   name suffix                phone  \
# 0    Dr.    Sra. Raquel Costela               0900 679 6629
# 1    Dr.           Enrico Rocha         +55 (011) 1317-1650
# 2  Srta.      Gabrielly Moreira             (081) 0799 7561
# 3   Sra.        Dr. Breno Viana            +55 51 1065 3617
# 4   Dra.  Maria Fernanda Aragão             (021) 7530 4238
# 5   Sra.          Joana Ribeiro                31 4747-0323
# 6   Sra.          Daniela Lopes             (031) 5418 0681
# 7   Sra.     Ana Laura da Rocha             (084) 9957-6181
# 8    Sr.    João Lucas da Cunha                84 8137 1655
# 9    Dr.             Davi Rocha            +55 84 4011-5333
#
#                           email  \
# 0    azevedosophie@yahoo.com.br
# 1           dsilveira@ig.com.br
# 2           hpeixoto@bol.com.br
# 3         rrodrigues@uol.com.br
# 4  da-conceicaoalicia@gmail.com
# 5        diogodias@yahoo.com.br
# 6              yporto@gmail.com
# 7      isadoramoraes@uol.com.br
# 8            diego36@bol.com.br
# 9          lmonteiro@bol.com.br
#
#                                              address
# 0  Condomínio João Pedro da Paz, 52\nAraguaia\n70...
# 1  Travessa Evelyn Oliveira, 56\nBeira Linha\n022...
# 2  Sítio Samuel Costela, 79\nConjunto Califórnia ...
# 3  Passarela de Moreira, 2\nTupi A\n10238083 Fari...
# 4  Alameda de Silva, 60\nSavassi\n42218-818 Nogue...
# 5  Área de Barbosa, 520\nMarajó\n50544723 da Roch...
# 6  Distrito Costa, 67\nMinaslandia\n66256195 Cost...
# 7  Trevo Laís Ribeiro, 41\nVila Canto Do Sabiá\n4...
# 8  Morro Farias, 5\nVila Jardim Leblon\n23248272 ...
# 9  Viela Lima, 63\nMala E Cuia\n34386900 Silveira...

# %%
########################################### CONNECT MYSQL ############################

from sqlalchemy import create_engine

## Parameter
engine      = 'mysql'
conect      = 'pymysql'
user        = 'root'
password    = 'root'
host        = 'localhost'
port        = "3306"
database    = 'world'
table       = 'tab_clientes2'


engine  = create_engine(f"{engine}+{conect}://{user}:{password}@{host}:{port}/{database}")
conn    = engine.connect()

connection = mysql.connector.connect(user=user,password=password,host=host,port=port,database=database)

print("Connection ok!")
# Out:
# Connection ok!

# %%
########################################### INSERT DATA INTO MYSQL ############################
records = df.values.tolist()

mySql_insert_query = f"""INSERT INTO {table} (prefix, name, suffix, phone,email,address)
                           VALUES (%s, %s, %s, %s, %s, %s) """


cursor = connection.cursor()
cursor.executemany(mySql_insert_query, records) #execute rows ingestion
connection.commit()

print(cursor.rowcount, f"Record inserted successfully into {table} table")
# Out:
# 10 Record inserted successfully into tab_clientes2 table

# %%
sql = f" SELECT * FROM {table} WHERE NAME IS NOT NULL "

df_time_series = pd.read_sql(sql, connection)
df_time_series.head()
# Out:
#   prefix                 name suffix             phone  \
# 0    Sr.  Pedro Lucas Ribeiro         +55 71 9833-4230
# 1    Sr.       Heloísa Moraes             21 7986-0081
# 2  Srta.          Evelyn Melo            0800-389-2530
# 3  Srta.      Antônio Pereira         +55 81 8953 7802
# 4    Sr.        Laura Moreira         +55 51 7810 5295
#
#                        email  \
# 0          xsales@uol.com.br
# 1           ynunes@ig.com.br
# 2  piresemanuelly@uol.com.br
# 3      thiagogomes@ig.com.br
# 4          kmendes@ig.com.br
#
#                                              address
# 0  Viaduto Catarina da Mata, 819\nNovo Glória\n18...
# 1  Via de Araújo, 9\nEstrela Do Oriente\n32198-40...
# 2  Pátio de Lopes, 87\nVila Antena\n10596362 Nune...
# 3    Parque Oliveira, 56\nSion\n00216-203 Souza / RR
# 4  Residencial Ana Beatriz Pires\nÁpia\n24916-184...

# %%
cursor.close()
connection.close()
print("End of task,MySQL connection is closed!")
# Out:
# End of task,MySQL connection is closed!
